# %%
import os
import torch
import torchaudio
import matplotlib.pyplot as plt
from src.metrics import *
from src.gest_segm import *
from src.dataset import *


# Exemple d'utilisation
file_directory = 'amicorpus/ES2002c/audio'
rrtm_dir =  'annot_prepare/results/rttm'

# Get waveforms
waveforms, sample_rate = get_waveform(file_directory)

features = extract_features(waveforms[0], sample_rate )

print(features.shape)
print(len(waveforms))
# Out:
# Processing amicorpus/ES2002c/audio/ES2002c.Array1-01.wav
# Loaded amicorpus/ES2002c/audio/ES2002c.Array1-01.wav with sample rate 16000 and waveform shape torch.Size([1, 38778880])
# Processing amicorpus/ES2002c/audio/ES2002c.Array1-02.wav
# Loaded amicorpus/ES2002c/audio/ES2002c.Array1-02.wav with sample rate 16000 and waveform shape torch.Size([1, 38778880])
# Processing amicorpus/ES2002c/audio/ES2002c.Array1-03.wav
# Loaded amicorpus/ES2002c/audio/ES2002c.Array1-03.wav with sample rate 16000 and waveform shape torch.Size([1, 38778880])
# Processing amicorpus/ES2002c/audio/ES2002c.Array1-04.wav
# Loaded amicorpus/ES2002c/audio/ES2002c.Array1-04.wav with sample rate 16000 and waveform shape torch.Size([1, 38778880])
# Processing amicorpus/ES2002c/audio/ES2002c.Array1-05.wav
# Loaded amicorpus/ES2002c/audio/ES2002c.Array1-05.wav with sample rate 16000 and waveform shape torch.Size([1, 38778880])
# Processing amicorpus/ES2002c/audio/ES2002c.Array1-06.wav
# Loaded amicorpus/ES2002c/audio/ES2002c.Array1-06.wav with sample rate 16000 and waveform shape torch.Size([1, 38778880])
# Processing amicorpus/ES2002c/audio/ES2002c.Array1-07.wav
# Loaded amicorpus/ES2002c/audio/ES2002c.Array1-07.wav with sample rate 16000 and waveform shape torch.Size([1, 38778880])
# Processing amicorpus/ES2002c/audio/ES2002c.Array1-08.wav
# Loaded amicorpus/ES2002c/audio/ES2002c.Array1-08.wav with sample rate 16000 and waveform shape torch.Size([1, 38778880])
# Starting computation of metrics...
# Calculating spectrograms...
# Spectrogram shape for microphone 1: torch.Size([1, 257, 501])
# Spectrogram shape for microphone 2: torch.Size([1, 257, 501])
# Spectrogram shape for microphone 3: torch.Size([1, 257, 501])
# Spectrogram shape for microphone 4: torch.Size([1, 257, 501])
# Spectrogram shape for microphone 5: torch.Size([1, 257, 501])
# Spectrogram shape for microphone 6: torch.Size([1, 257, 501])
# Spectrogram shape for microphone 7: torch.Size([1, 257, 501])
# Spectrogram shape for microphone 8: torch.Size([1, 257, 501])
# Calculating LPS...
# LPS shape for microphone 1: torch.Size([1, 257, 501])
# LPS shape for microphone 2: torch.Size([1, 257, 501])
# LPS shape for microphone 3: torch.Size([1, 257, 501])
# LPS shape for microphone 4: torch.Size([1, 257, 501])
# LPS shape for microphone 5: torch.Size([1, 257, 501])
# LPS shape for microphone 6: torch.Size([1, 257, 501])
# LPS shape for microphone 7: torch.Size([1, 257, 501])
# LPS shape for microphone 8: torch.Size([1, 257, 501])
# Calculating phases...
# Phase shape for microphone 1: torch.Size([1, 257, 501])
# Phase shape for microphone 2: torch.Size([1, 257, 501])
# Phase shape for microphone 3: torch.Size([1, 257, 501])
# Phase shape for microphone 4: torch.Size([1, 257, 501])
# Phase shape for microphone 5: torch.Size([1, 257, 501])
# Phase shape for microphone 6: torch.Size([1, 257, 501])
# Phase shape for microphone 7: torch.Size([1, 257, 501])
# Phase shape for microphone 8: torch.Size([1, 257, 501])
# Calculating IPD for provided pairs of microphones...
# Calculating IPD for Microphones 1 and 5
# IPD shape for microphones 1 and 5: torch.Size([1, 257, 501])
# Calculating IPD for Microphones 2 and 6
# IPD shape for microphones 2 and 6: torch.Size([1, 257, 501])
# Calculating IPD for Microphones 3 and 7
# IPD shape for microphones 3 and 7: torch.Size([1, 257, 501])
# Calculating IPD for Microphones 4 and 8
# IPD shape for microphones 4 and 8: torch.Size([1, 257, 501])
# Calculating AF for provided pairs of microphones...
# Calculating AF contribution for Microphones 1 and 5 with θ=0 radians
# Calculating AF contribution for Microphones 2 and 6 with θ=0 radians
# Calculating AF contribution for Microphones 3 and 7 with θ=0 radians
# Calculating AF contribution for Microphones 4 and 8 with θ=0 radians
# AF shape with θ=0 radians: torch.Size([257, 501])
# Calculating AF contribution for Microphones 1 and 5 with θ=1.5707963267948966 radians
# Calculating AF contribution for Microphones 2 and 6 with θ=1.5707963267948966 radians
# Calculating AF contribution for Microphones 3 and 7 with θ=1.5707963267948966 radians
# Calculating AF contribution for Microphones 4 and 8 with θ=1.5707963267948966 radians
# AF shape with θ=1.5707963267948966 radians: torch.Size([257, 501])
# Calculating AF contribution for Microphones 1 and 5 with θ=3.141592653589793 radians
# Calculating AF contribution for Microphones 2 and 6 with θ=3.141592653589793 radians
# Calculating AF contribution for Microphones 3 and 7 with θ=3.141592653589793 radians
# Calculating AF contribution for Microphones 4 and 8 with θ=3.141592653589793 radians
# AF shape with θ=3.141592653589793 radians: torch.Size([257, 501])
# Calculating AF contribution for Microphones 1 and 5 with θ=4.71238898038469 radians
# Calculating AF contribution for Microphones 2 and 6 with θ=4.71238898038469 radians
# Calculating AF contribution for Microphones 3 and 7 with θ=4.71238898038469 radians
# Calculating AF contribution for Microphones 4 and 8 with θ=4.71238898038469 radians
# AF shape with θ=4.71238898038469 radians: torch.Size([257, 501])
# Finished computation of metrics.
# Processing IPD features...
# IPD array shape: torch.Size([4, 257, 501])
# Processing AF features...
# AF array shape: torch.Size([4, 257, 501])
# Processing LPS features...
# LPS array shape: torch.Size([8, 257, 501])
# Concatenating all features into a single feature array...
# Final feature array shape: torch.Size([16, 257, 501])
# torch.Size([16, 257, 501])
# 604
# /Users/jerome/Desktop/internship ai/src/dataset.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   ipd_array_list = [torch.tensor(ipd_pairs[pair]) for pair in mic_pairs]
# /Users/jerome/Desktop/internship ai/src/dataset.py:36: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   af_array_list = [torch.tensor(af_dict[theta]).unsqueeze(0) for theta in theta_values]  # Add an extra dimension
# /Users/jerome/Desktop/internship ai/src/dataset.py:41: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   lps_array_list = [torch.tensor(lp) for lp in lps]
